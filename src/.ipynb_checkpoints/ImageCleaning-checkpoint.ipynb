# %% [markdown]
# # Image Cleaning
#
# Writing image analysis algorithm for microscope images can become very challening due to the noise present in images. There are multiple sources for this noise. Many times the sample labelling is weak and sensor gain needs to be pushed up recover image signal. Other time, presense of a bright flourescence in one channel bleeds over to another and washes the other image. Or to capture images quickly, exposure time is reduced.
#
# Noise in itself isn't a big problem if we are not performing quantitative analysis from the images. Since I have to do that, I have seen that writing robust algorithms which work in presense of large image noise is often very challenging. So here I explore if I can use auto-encoder to clean microscope images and make my life easier while I design image processing algorithm.
#
# My basic idea in this project is to use a deep learning model to clean microscope images. My deep learning model is based on convolutional autoencoders. To train the model I synthetically generate clean and noisy microscopic images. In image generation I try to synthesis features typically seen microscopic images. Then I distort these clean images considering theoritical optical model of the microscope and add noise to it.
#
# After training the model, I noticed that I was able to recover back clean images from very noisy images. Here is a sneak peak of some of the results. I am pretty amazed by how well the model was able to restore the noisy images back to the original clean image.

# %%
# Standard libraries
import numpy as np
import numpy.matlib
import tensorflow as tf
import scipy.io as sio
from scipy import ndimage
import time
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline 

# My support code
import image_generation as imgen
from imshow3D import imshow3D
from model import ImageCleaner

# %% [markdown]
# ## Synthetic Image Generation
#
#
# ### Theoretical true clean image
# The first step in image generation is creating a general biological sample. This in itself is a very difficult task. How do you best represnt features of fluroscently labelled biological sample.
#
# I create sudo-biological sample by creating a clean 3D image with randomly seeded blobs of various size and shapes. The blobs are generated by a gaussian distribution of varying sigma in each direction. For example, here I will create a 64x64x64 volume and visualize in slice by slice from my custom 3D imageviewer based on ipywidgets.
#
# This is my theoretical true clean image, without any optical distortion or image noise.

# %%
sizeI = np.array([64,64,64])
sigma_pts = {140:1.5*np.array([1,1,1]), 
            70:1.75*np.array([1,1,1]), 
            35:2*np.array([1,1,1])} # Number of particle and corresponding mean sigma
img = np.zeros(sizeI)

for nPts, sigma in sigma_pts.items():
    # Vary number of points and sigma
    nPts = np.round(np.random.poisson(nPts))
    pts = imgen.random_seed_locations(nPts, sizeI)
    sigma = (sigma + np.random.normal(0, 0.2*sigma[0], 
                        size=(nPts,3)))
    sigma = np.absolute(sigma)
    
    # Generate img
    img = np.maximum(imgen.seedBeadsN(pts, sizeI, sigma), img)

# Temporary visualize for Github notebook rendering
plt.figure(figsize=(8,6))
plt.imshow(img[:,:,0], cmap='plasma', vmin=0, vmax=1)
plt.colorbar()

# Visuzlize using this on local computer. Commenting this because Github 
# does not show ipywidgets

# imshow3D(img)

# %% [markdown]
# ### Blur Image with a PSF
#
# Every optical system has its own point spread function (psf) which blurs the image captured by it. In this case, we simulate a psf from Born & Wolf 3D optical model, and blur the image with it.
#
# We can see that because of the psf, images lose their sharpness and it becomes more challending to segment neighboring blobs. This is also a true problem faced while segmenting neigboring small particles in microscope images

# %%
psf = sio.loadmat('../data/psf.mat')
psf = psf['psf']
psf = psf/np.sum(psf)


blurred_img = ndimage.convolve(img, psf, mode='constant', cval=0.0)

# Show the two images side-by side to visualize the original image (left) vs 
# blurring effect (right)

# Temporary visualize for Github notebook rendering
plt.figure(figsize=(16,6))
plt.imshow(np.squeeze(np.append(img[0,:,:], blurred_img[0,:,:], axis=1)), 
           cmap='plasma', vmin=0, vmax=1)
plt.colorbar()

# Visuzlize using this on local computer. Commenting this because Github 
# does not show ipywidgets
# imshow3D(np.squeeze(np.append(img, blurred_img, axis=2)), 0, (12,12))

# %% [markdown]
# ### Image intensity partial sensor range coverage
#
# Moreover the image intensity does not cover the entire spread of the avaiable dynamic range in the sensor. We simulate this over here

# %%
im_range = {'lower':0.2, 'upper':0.2, 'gap':0.6}

lower = np.random.random()*im_range['lower']
upper = np.random.random()*im_range['upper'] + im_range['gap']
range_img = imgen.change_im_range(blurred_img, lower, upper)

# Show the two images side-by side to visualize the original image (left) vs 
# the cropped sensor range image intensity coverage(right)

# Temporary visualize for Github notebook rendering
plt.figure(figsize=(16,6))
plt.imshow(np.squeeze(np.append(img[0,:,:], range_img[0,:,:], axis=1)), 
           cmap='plasma', vmin=0, vmax=1)
plt.colorbar()

# Visuzlize using this on local computer. Commenting this because Github 
# does not show ipywidgets

# imshow3D(np.squeeze(np.append(img, range_img, axis=2)), 0, (12,12))

# %% [markdown]
# ### Sensor shot noise
#
# To generate the simulated images for each signal-to-noise ratio (SNr) from shot noise, we scale the image intensity such that the peak image intensity is equal to the SNr squared. Then each voxel intensity is replaced by a random number drawn from a Poisson’s distribution with its mean equal to the original intensity.

# %%
snr = 12
noise_img = imgen.add_poisson_noise(range_img, snr)

# Show the two images side-by side to visualize the original image (left) vs 
# image with sensor shot noise(right)

# Temporary visualize for Github notebook rendering
plt.figure(figsize=(16,6))
plt.imshow(np.squeeze(np.append(img[0,:,:], noise_img[0,:,:], axis=1)), 
           cmap='plasma', vmin=0, vmax=1)
plt.colorbar()


# Visuzlize using this on local computer. Commenting this because Github 
# does not show ipywidgets

# imshow3D(np.squeeze(np.append(img, noise_img, axis=2)), 0, (12,12))

# %% [markdown]
# ### Gaussian sensor noise
#
# At last, we add gaussian noise to the image to simulate the usual gaussian noise present in any image. This is the last step in our synthetic noisy image generation. We can see how much different the noisy images are in comparison to the original images

# %%
gauss_noise = {'mean':0, 'std':0.02}
noise_img = imgen.add_gaussian_noise(noise_img, gauss_noise['mean'], gauss_noise['std'])

# Show the two images side-by side to visualize the original image (left) vs 
# image with gaussian sensor noise(right)

# Temporary visualize for Github notebook rendering
plt.figure(figsize=(16,6))
plt.imshow(np.squeeze(np.append(img[0,:,:], noise_img[0,:,:], axis=1)), 
           cmap='plasma', vmin=0, vmax=1)
plt.colorbar()

# Visuzlize using this on local computer. Commenting this because Github 
# does not show ipywidgets

# imshow3D(np.squeeze(np.append(img, noise_img, axis=2)), 0, (12,12))

# %% [markdown]
# ### Synthetic dataset generation for training and test the model
#
# Caution: This step takes time, so run it with some patience. On my computer it took about 13 seconds to generate 1000 images.
#
# I generate 27000 training images with 3000 test/validation images.

# %%
# Image generation parameters
n_images = 30000
slices = [x for x in range(14, 114, 5)]
sizeI = np.array([64,64,128])
sigmaPts = {280:1.5*np.array([1,1,1]), 140:1.75*np.array([1,1,1]), 70:2*np.array([1,1,1])}
im_range = {'lower':0.2, 'upper':0.2, 'gap':0.6}
gauss_noise = {'mean':0, 'std':0.01}
snr = 12
psf = sio.loadmat('../data/psf.mat')
psf = psf['psf']
psf = psf/np.sum(psf)

# Generate Images
start = time.time()
X_train, y_train = imgen.create_im_2D(n_images, sizeI, slices, sigmaPts, psf,snr=snr, 
                            im_range=im_range, gauss_noise=gauss_noise)
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.10)
end = time.time()
print('Time elapsed in data generation: %0.3f seconds' % (end - start))
# Out:
# Time elapsed in data generation: 347.909 seconds

# %%
# Visualize synthetically generated images. Clean on left vs noisy on right

# Temporary visualize for Github notebook rendering
plt.figure(figsize=(16,6))
plt.imshow(np.squeeze(np.append(X_test[0,:,:,:], y_test[0,:,:,:], axis=1)), 
           cmap='plasma', vmin=0, vmax=1)
plt.colorbar()

# Visuzlize using this on local computer. Commenting this because Github 
# does not show ipywidgets
# imshow3D(np.squeeze(np.append(X_train[:30,:,:,:], y_train[:30,:,:,:], axis=2)),
#          0, (12,12))

# %% [markdown]
# ## Convolutional autoencoder model
#
# I use a convolutional autoencoder model to recover back the original image from the noisy image. The model architecture can be seen in the figure below
#
#
# I trained various models, and the model shown above gives the best accuracy scores. In the this model, I use three layers of convolution with relu activation to reduce the feature size from 64x64x1 to 8x8x45. Then I use four layers of transposed convolution with relue activatation to increase the feature size from 8x8x45 to 128x128x10. The I finally use a convolution layer coupled with sigmoid activation to recover the cleaned image.
#
# I minize the cross-entropy loss in training using Adam optimizer to train the model.
#
# #### Evaluation parameter
# In the model I define accuracy in terms of error. Here error is defined as the mean of absolute image intensity difference between noisy and the true clean image.

# %%
# The model is implemented in model.py with Keras like api to fit, evaluate, predict, save and restore.
# This allows for clean training process over here. The model is however built using Tensorflow, and
# implemented with Keras/scikit-learn like api

model = ImageCleaner()
model.lr = 0.001
# model.dropout = 0.2

model.fit(x=X_train, 
          y=y_train, 
          epochs=200, 
          val_x=X_test, 
          val_y=y_test,
          save_path='./checkpoints/mymodel')
# Out:
# Epoch 1/200
# 27000/27000 [==============================] - 192s 7ms/step - Loss: 0.2871 - Error: 0.0412
# Validation loss: 0.2707 - Validation Error: 0.0228
# Epoch 2/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2696 - Error: 0.0211
# Validation loss: 0.2709 - Validation Error: 0.0243
# Epoch 3/200
# 27000/27000 [==============================] - 193s 7ms/step - Loss: 0.2688 - Error: 0.0192
# Validation loss: 0.2688 - Validation Error: 0.0187
# Epoch 4/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2683 - Error: 0.0180
# Validation loss: 0.2682 - Validation Error: 0.0169
# Epoch 5/200
# 27000/27000 [==============================] - 193s 7ms/step - Loss: 0.2680 - Error: 0.0172
# Validation loss: 0.2679 - Validation Error: 0.0162
# Epoch 6/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2678 - Error: 0.0169
# Validation loss: 0.2681 - Validation Error: 0.0172
# Epoch 7/200
# 27000/27000 [==============================] - 193s 7ms/step - Loss: 0.2676 - Error: 0.0163
# Validation loss: 0.2678 - Validation Error: 0.0159
# Epoch 8/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2675 - Error: 0.0160
# Validation loss: 0.2677 - Validation Error: 0.0160
# Epoch 9/200
# 27000/27000 [==============================] - 193s 7ms/step - Loss: 0.2674 - Error: 0.0158
# Validation loss: 0.2675 - Validation Error: 0.0151
# Epoch 10/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2673 - Error: 0.0155
# Validation loss: 0.2674 - Validation Error: 0.0149
# Epoch 11/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2673 - Error: 0.0153
# Validation loss: 0.2674 - Validation Error: 0.0147
# Epoch 12/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2672 - Error: 0.0151
# Validation loss: 0.2673 - Validation Error: 0.0143
# Epoch 13/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2671 - Error: 0.0148
# Validation loss: 0.2675 - Validation Error: 0.0151
# Epoch 14/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2671 - Error: 0.0147
# Validation loss: 0.2673 - Validation Error: 0.0141
# Epoch 15/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2670 - Error: 0.0144
# Validation loss: 0.2674 - Validation Error: 0.0148
# Epoch 16/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2670 - Error: 0.0145
# Validation loss: 0.2673 - Validation Error: 0.0139
# Epoch 17/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2669 - Error: 0.0143
# Validation loss: 0.2671 - Validation Error: 0.0137
# Epoch 18/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2669 - Error: 0.0141
# Validation loss: 0.2672 - Validation Error: 0.0141
# Epoch 19/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2669 - Error: 0.0141
# Validation loss: 0.2671 - Validation Error: 0.0137
# Epoch 20/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2668 - Error: 0.0139
# Validation loss: 0.2672 - Validation Error: 0.0140
# Epoch 21/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2668 - Error: 0.0140
# Validation loss: 0.2670 - Validation Error: 0.0134
# Epoch 22/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2668 - Error: 0.0138
# Validation loss: 0.2680 - Validation Error: 0.0170
# Epoch 23/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2668 - Error: 0.0138
# Validation loss: 0.2670 - Validation Error: 0.0133
# Epoch 24/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2668 - Error: 0.0137
# Validation loss: 0.2671 - Validation Error: 0.0135
# Epoch 25/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2667 - Error: 0.0136
# Validation loss: 0.2674 - Validation Error: 0.0150
# Epoch 26/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2667 - Error: 0.0135
# Validation loss: 0.2670 - Validation Error: 0.0133
# Epoch 27/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2667 - Error: 0.0136
# Validation loss: 0.2670 - Validation Error: 0.0133
# Epoch 28/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2667 - Error: 0.0134
# Validation loss: 0.2671 - Validation Error: 0.0139
# Epoch 29/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2667 - Error: 0.0133
# Validation loss: 0.2670 - Validation Error: 0.0134
# Epoch 30/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2667 - Error: 0.0133
# Validation loss: 0.2671 - Validation Error: 0.0138
# Epoch 31/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2667 - Error: 0.0133
# Validation loss: 0.2671 - Validation Error: 0.0137
# Epoch 32/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2666 - Error: 0.0132
# Validation loss: 0.2669 - Validation Error: 0.0134
# Epoch 33/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2666 - Error: 0.0131
# Validation loss: 0.2670 - Validation Error: 0.0136
# Epoch 34/200
# 27000/27000 [==============================] - 196s 7ms/step - Loss: 0.2666 - Error: 0.0132
# Validation loss: 0.2670 - Validation Error: 0.0134
# Epoch 35/200
# 27000/27000 [==============================] - 196s 7ms/step - Loss: 0.2666 - Error: 0.0131
# Validation loss: 0.2669 - Validation Error: 0.0131
# Epoch 36/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2666 - Error: 0.0131
# Validation loss: 0.2668 - Validation Error: 0.0128
# Epoch 37/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2666 - Error: 0.0130
# Validation loss: 0.2668 - Validation Error: 0.0128
# Epoch 38/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2666 - Error: 0.0130
# Validation loss: 0.2668 - Validation Error: 0.0129
# Epoch 39/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2666 - Error: 0.0130
# Validation loss: 0.2669 - Validation Error: 0.0129
# Epoch 40/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2666 - Error: 0.0129
# Validation loss: 0.2668 - Validation Error: 0.0126
# Epoch 41/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2666 - Error: 0.0130
# Validation loss: 0.2672 - Validation Error: 0.0141
# Epoch 42/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2666 - Error: 0.0129
# Validation loss: 0.2668 - Validation Error: 0.0125
# Epoch 43/200
# 27000/27000 [==============================] - 196s 7ms/step - Loss: 0.2665 - Error: 0.0129
# Validation loss: 0.2669 - Validation Error: 0.0129
# Epoch 44/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2665 - Error: 0.0128
# Validation loss: 0.2668 - Validation Error: 0.0125
# Epoch 45/200
# 27000/27000 [==============================] - 196s 7ms/step - Loss: 0.2665 - Error: 0.0128
# Validation loss: 0.2669 - Validation Error: 0.0131
# Epoch 46/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2665 - Error: 0.0127
# Validation loss: 0.2668 - Validation Error: 0.0125
# Epoch 47/200
# 27000/27000 [==============================] - 196s 7ms/step - Loss: 0.2665 - Error: 0.0128
# Validation loss: 0.2670 - Validation Error: 0.0131
# Epoch 48/200
# 27000/27000 [==============================] - 196s 7ms/step - Loss: 0.2665 - Error: 0.0128
# Validation loss: 0.2669 - Validation Error: 0.0130
# Epoch 49/200
# 27000/27000 [==============================] - 196s 7ms/step - Loss: 0.2665 - Error: 0.0128
# Validation loss: 0.2670 - Validation Error: 0.0130
# Epoch 50/200
# 27000/27000 [==============================] - 196s 7ms/step - Loss: 0.2665 - Error: 0.0128
# Validation loss: 0.2668 - Validation Error: 0.0125
# Epoch 51/200
# 27000/27000 [==============================] - 197s 7ms/step - Loss: 0.2665 - Error: 0.0127
# Validation loss: 0.2669 - Validation Error: 0.0129
# Epoch 52/200
# 27000/27000 [==============================] - 196s 7ms/step - Loss: 0.2665 - Error: 0.0127
# Validation loss: 0.2668 - Validation Error: 0.0125
# Epoch 53/200
# 27000/27000 [==============================] - 193s 7ms/step - Loss: 0.2665 - Error: 0.0127
# Validation loss: 0.2669 - Validation Error: 0.0129
# Epoch 54/200
# 27000/27000 [==============================] - 193s 7ms/step - Loss: 0.2665 - Error: 0.0127
# Validation loss: 0.2668 - Validation Error: 0.0124
# Epoch 55/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2665 - Error: 0.0126
# Validation loss: 0.2668 - Validation Error: 0.0126
# Epoch 56/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2665 - Error: 0.0127
# Validation loss: 0.2668 - Validation Error: 0.0125
# Epoch 57/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2665 - Error: 0.0126
# Validation loss: 0.2667 - Validation Error: 0.0123
# Epoch 58/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2665 - Error: 0.0126
# Validation loss: 0.2668 - Validation Error: 0.0124
# Epoch 59/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2665 - Error: 0.0126
# Validation loss: 0.2668 - Validation Error: 0.0124
# Epoch 60/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2664 - Error: 0.0125
# Validation loss: 0.2667 - Validation Error: 0.0123
# Epoch 61/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2665 - Error: 0.0126
# Validation loss: 0.2668 - Validation Error: 0.0126
# Epoch 62/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2665 - Error: 0.0126
# Validation loss: 0.2669 - Validation Error: 0.0130
# Epoch 63/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2665 - Error: 0.0126
# Validation loss: 0.2670 - Validation Error: 0.0134
# Epoch 64/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2664 - Error: 0.0125
# Validation loss: 0.2667 - Validation Error: 0.0123
# Epoch 65/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2664 - Error: 0.0125
# Validation loss: 0.2668 - Validation Error: 0.0125
# Epoch 66/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2664 - Error: 0.0124
# Validation loss: 0.2667 - Validation Error: 0.0123
# Epoch 67/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2664 - Error: 0.0125
# Validation loss: 0.2670 - Validation Error: 0.0130
# Epoch 68/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2664 - Error: 0.0125
# Validation loss: 0.2667 - Validation Error: 0.0124
# Epoch 69/200
# 27000/27000 [==============================] - 196s 7ms/step - Loss: 0.2664 - Error: 0.0125
# Validation loss: 0.2667 - Validation Error: 0.0123
# Epoch 70/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2664 - Error: 0.0124
# Validation loss: 0.2667 - Validation Error: 0.0124
# Epoch 71/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2664 - Error: 0.0124
# Validation loss: 0.2668 - Validation Error: 0.0123
# Epoch 72/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2664 - Error: 0.0124
# Validation loss: 0.2667 - Validation Error: 0.0124
# Epoch 73/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2664 - Error: 0.0124
# Validation loss: 0.2668 - Validation Error: 0.0128
# Epoch 74/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2664 - Error: 0.0124
# Validation loss: 0.2667 - Validation Error: 0.0123
# Epoch 75/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2664 - Error: 0.0124
# Validation loss: 0.2668 - Validation Error: 0.0125
# Epoch 76/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2664 - Error: 0.0123
# Validation loss: 0.2667 - Validation Error: 0.0123
# Epoch 77/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2664 - Error: 0.0124
# Validation loss: 0.2669 - Validation Error: 0.0129
# Epoch 78/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2664 - Error: 0.0124
# Validation loss: 0.2667 - Validation Error: 0.0122
# Epoch 79/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2664 - Error: 0.0123
# Validation loss: 0.2668 - Validation Error: 0.0128
# Epoch 80/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2664 - Error: 0.0124
# Validation loss: 0.2667 - Validation Error: 0.0122
# Epoch 81/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2664 - Error: 0.0123
# Validation loss: 0.2667 - Validation Error: 0.0122
# Epoch 82/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2664 - Error: 0.0123
# Validation loss: 0.2667 - Validation Error: 0.0123
# Epoch 83/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2664 - Error: 0.0123
# Validation loss: 0.2667 - Validation Error: 0.0125
# Epoch 84/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2664 - Error: 0.0123
# Validation loss: 0.2668 - Validation Error: 0.0128
# Epoch 85/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2664 - Error: 0.0123
# Validation loss: 0.2668 - Validation Error: 0.0123
# Epoch 86/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2664 - Error: 0.0123
# Validation loss: 0.2668 - Validation Error: 0.0130
# Epoch 87/200
# 27000/27000 [==============================] - 197s 7ms/step - Loss: 0.2664 - Error: 0.0123
# Validation loss: 0.2667 - Validation Error: 0.0123
# Epoch 88/200
# 27000/27000 [==============================] - 196s 7ms/step - Loss: 0.2664 - Error: 0.0123
# Validation loss: 0.2667 - Validation Error: 0.0123
# Epoch 89/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2664 - Error: 0.0123
# Validation loss: 0.2667 - Validation Error: 0.0124
# Epoch 90/200
# 27000/27000 [==============================] - 201s 7ms/step - Loss: 0.2664 - Error: 0.0122
# Validation loss: 0.2668 - Validation Error: 0.0126
# Epoch 91/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2664 - Error: 0.0123
# Validation loss: 0.2668 - Validation Error: 0.0122
# Epoch 92/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2664 - Error: 0.0122
# Validation loss: 0.2667 - Validation Error: 0.0121
# Epoch 93/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2664 - Error: 0.0122
# Validation loss: 0.2667 - Validation Error: 0.0121
# Epoch 94/200
# 27000/27000 [==============================] - 196s 7ms/step - Loss: 0.2664 - Error: 0.0122
# Validation loss: 0.2667 - Validation Error: 0.0123
# Epoch 95/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2664 - Error: 0.0122
# Validation loss: 0.2667 - Validation Error: 0.0121
# Epoch 96/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2664 - Error: 0.0122
# Validation loss: 0.2668 - Validation Error: 0.0125
# Epoch 97/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2664 - Error: 0.0122
# Validation loss: 0.2667 - Validation Error: 0.0121
# Epoch 98/200
# 27000/27000 [==============================] - 196s 7ms/step - Loss: 0.2663 - Error: 0.0122
# Validation loss: 0.2667 - Validation Error: 0.0122
# Epoch 99/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2664 - Error: 0.0123
# Validation loss: 0.2667 - Validation Error: 0.0122
# Epoch 100/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2663 - Error: 0.0122
# Validation loss: 0.2668 - Validation Error: 0.0124
# Epoch 101/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2664 - Error: 0.0123
# Validation loss: 0.2668 - Validation Error: 0.0126
# Epoch 102/200
# 27000/27000 [==============================] - 196s 7ms/step - Loss: 0.2663 - Error: 0.0122
# Validation loss: 0.2670 - Validation Error: 0.0134
# Epoch 103/200
# 27000/27000 [==============================] - 196s 7ms/step - Loss: 0.2663 - Error: 0.0121
# Validation loss: 0.2669 - Validation Error: 0.0126
# Epoch 104/200
# 27000/27000 [==============================] - 196s 7ms/step - Loss: 0.2663 - Error: 0.0122
# Validation loss: 0.2668 - Validation Error: 0.0126
# Epoch 105/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2663 - Error: 0.0121
# Validation loss: 0.2667 - Validation Error: 0.0122
# Epoch 106/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2663 - Error: 0.0121
# Validation loss: 0.2667 - Validation Error: 0.0122
# Epoch 107/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2663 - Error: 0.0121
# Validation loss: 0.2667 - Validation Error: 0.0122
# Epoch 108/200
# 27000/27000 [==============================] - 193s 7ms/step - Loss: 0.2663 - Error: 0.0122
# Validation loss: 0.2667 - Validation Error: 0.0122
# Epoch 109/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2663 - Error: 0.0121
# Validation loss: 0.2668 - Validation Error: 0.0130
# Epoch 110/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2663 - Error: 0.0121
# Validation loss: 0.2669 - Validation Error: 0.0129
# Epoch 111/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2663 - Error: 0.0121
# Validation loss: 0.2667 - Validation Error: 0.0124
# Epoch 112/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2663 - Error: 0.0121
# Validation loss: 0.2667 - Validation Error: 0.0121
# Epoch 113/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2663 - Error: 0.0121
# Validation loss: 0.2667 - Validation Error: 0.0121
# Epoch 114/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2663 - Error: 0.0121
# Validation loss: 0.2667 - Validation Error: 0.0125
# Epoch 115/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2663 - Error: 0.0121
# Validation loss: 0.2667 - Validation Error: 0.0121
# Epoch 116/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2663 - Error: 0.0122
# Validation loss: 0.2667 - Validation Error: 0.0121
# Epoch 117/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2663 - Error: 0.0121
# Validation loss: 0.2669 - Validation Error: 0.0128
# Epoch 118/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2663 - Error: 0.0121
# Validation loss: 0.2667 - Validation Error: 0.0123
# Epoch 119/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2663 - Error: 0.0121
# Validation loss: 0.2667 - Validation Error: 0.0122
# Epoch 120/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2663 - Error: 0.0121
# Validation loss: 0.2667 - Validation Error: 0.0122
# Epoch 121/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2663 - Error: 0.0121
# Validation loss: 0.2667 - Validation Error: 0.0120
# Epoch 122/200
# 27000/27000 [==============================] - 198s 7ms/step - Loss: 0.2663 - Error: 0.0121
# Validation loss: 0.2667 - Validation Error: 0.0122
# Epoch 123/200
# 27000/27000 [==============================] - 201s 7ms/step - Loss: 0.2663 - Error: 0.0121
# Validation loss: 0.2666 - Validation Error: 0.0120
# Epoch 124/200
# 27000/27000 [==============================] - 199s 7ms/step - Loss: 0.2663 - Error: 0.0121
# Validation loss: 0.2667 - Validation Error: 0.0122
# Epoch 125/200
# 27000/27000 [==============================] - 199s 7ms/step - Loss: 0.2663 - Error: 0.0121
# Validation loss: 0.2667 - Validation Error: 0.0122
# Epoch 126/200
# 27000/27000 [==============================] - 200s 7ms/step - Loss: 0.2663 - Error: 0.0121
# Validation loss: 0.2668 - Validation Error: 0.0126
# Epoch 127/200
# 27000/27000 [==============================] - 200s 7ms/step - Loss: 0.2663 - Error: 0.0121
# Validation loss: 0.2667 - Validation Error: 0.0122
# Epoch 128/200
# 27000/27000 [==============================] - 200s 7ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2667 - Validation Error: 0.0121
# Epoch 129/200
# 27000/27000 [==============================] - 200s 7ms/step - Loss: 0.2663 - Error: 0.0121
# Validation loss: 0.2666 - Validation Error: 0.0121
# Epoch 130/200
# 27000/27000 [==============================] - 199s 7ms/step - Loss: 0.2663 - Error: 0.0121
# Validation loss: 0.2667 - Validation Error: 0.0126
# Epoch 131/200
# 27000/27000 [==============================] - 200s 7ms/step - Loss: 0.2663 - Error: 0.0121
# Validation loss: 0.2667 - Validation Error: 0.0121
# Epoch 132/200
# 27000/27000 [==============================] - 203s 8ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2666 - Validation Error: 0.0120
# Epoch 133/200
# 27000/27000 [==============================] - 206s 8ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2667 - Validation Error: 0.0121
# Epoch 134/200
# 27000/27000 [==============================] - 207s 8ms/step - Loss: 0.2663 - Error: 0.0121
# Validation loss: 0.2671 - Validation Error: 0.0137
# Epoch 135/200
# 27000/27000 [==============================] - 220s 8ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2667 - Validation Error: 0.0123
# Epoch 136/200
# 27000/27000 [==============================] - 211s 8ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2667 - Validation Error: 0.0122
# Epoch 137/200
# 27000/27000 [==============================] - 198s 7ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2668 - Validation Error: 0.0128
# Epoch 138/200
# 27000/27000 [==============================] - 198s 7ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2667 - Validation Error: 0.0125
# Epoch 139/200
# 27000/27000 [==============================] - 198s 7ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2666 - Validation Error: 0.0121
# Epoch 140/200
# 27000/27000 [==============================] - 200s 7ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2668 - Validation Error: 0.0124
# Epoch 141/200
# 27000/27000 [==============================] - 200s 7ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2667 - Validation Error: 0.0123
# Epoch 142/200
# 27000/27000 [==============================] - 199s 7ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2668 - Validation Error: 0.0127
# Epoch 143/200
# 27000/27000 [==============================] - 199s 7ms/step - Loss: 0.2663 - Error: 0.0121
# Validation loss: 0.2667 - Validation Error: 0.0123
# Epoch 144/200
# 27000/27000 [==============================] - 198s 7ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2667 - Validation Error: 0.0122
# Epoch 145/200
# 27000/27000 [==============================] - 198s 7ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2667 - Validation Error: 0.0125
# Epoch 146/200
# 27000/27000 [==============================] - 199s 7ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2667 - Validation Error: 0.0120
# Epoch 147/200
# 27000/27000 [==============================] - 198s 7ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2666 - Validation Error: 0.0120
# Epoch 148/200
# 27000/27000 [==============================] - 198s 7ms/step - Loss: 0.2663 - Error: 0.0121
# Validation loss: 0.2669 - Validation Error: 0.0132
# Epoch 149/200
# 27000/27000 [==============================] - 198s 7ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2666 - Validation Error: 0.0119
# Epoch 150/200
# 27000/27000 [==============================] - 198s 7ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2666 - Validation Error: 0.0120
# Epoch 151/200
# 27000/27000 [==============================] - 198s 7ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2667 - Validation Error: 0.0120
# Epoch 152/200
# 27000/27000 [==============================] - 199s 7ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2666 - Validation Error: 0.0120
# Epoch 153/200
# 27000/27000 [==============================] - 199s 7ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2666 - Validation Error: 0.0121
# Epoch 154/200
# 27000/27000 [==============================] - 199s 7ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2667 - Validation Error: 0.0123
# Epoch 155/200
# 27000/27000 [==============================] - 199s 7ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2667 - Validation Error: 0.0126
# Epoch 156/200
# 27000/27000 [==============================] - 198s 7ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2667 - Validation Error: 0.0120
# Epoch 157/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2668 - Validation Error: 0.0124
# Epoch 158/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2667 - Validation Error: 0.0122
# Epoch 159/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2667 - Validation Error: 0.0120
# Epoch 160/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2666 - Validation Error: 0.0118
# Epoch 161/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2666 - Validation Error: 0.0120
# Epoch 162/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2666 - Validation Error: 0.0121
# Epoch 163/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2667 - Validation Error: 0.0121
# Epoch 164/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2667 - Validation Error: 0.0119
# Epoch 165/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2666 - Validation Error: 0.0119
# Epoch 166/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2669 - Validation Error: 0.0133
# Epoch 167/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2667 - Validation Error: 0.0122
# Epoch 168/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2667 - Validation Error: 0.0123
# Epoch 169/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2666 - Validation Error: 0.0119
# Epoch 170/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2667 - Validation Error: 0.0121
# Epoch 171/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2666 - Validation Error: 0.0119
# Epoch 172/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2667 - Validation Error: 0.0124
# Epoch 173/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2666 - Validation Error: 0.0118
# Epoch 174/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2666 - Validation Error: 0.0119
# Epoch 175/200
# 27000/27000 [==============================] - 196s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2666 - Validation Error: 0.0119
# Epoch 176/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2666 - Validation Error: 0.0119
# Epoch 177/200
# 27000/27000 [==============================] - 194s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2667 - Validation Error: 0.0119
# Epoch 178/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2668 - Validation Error: 0.0128
# Epoch 179/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2671 - Validation Error: 0.0136
# Epoch 180/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2663 - Error: 0.0120
# Validation loss: 0.2667 - Validation Error: 0.0122
# Epoch 181/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2666 - Validation Error: 0.0118
# Epoch 182/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2668 - Validation Error: 0.0127
# Epoch 183/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2666 - Validation Error: 0.0120
# Epoch 184/200
# 27000/27000 [==============================] - 196s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2666 - Validation Error: 0.0121
# Epoch 185/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2666 - Validation Error: 0.0118
# Epoch 186/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2666 - Validation Error: 0.0120
# Epoch 187/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2666 - Validation Error: 0.0120
# Epoch 188/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2667 - Validation Error: 0.0124
# Epoch 189/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2666 - Validation Error: 0.0120
# Epoch 190/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2666 - Validation Error: 0.0120
# Epoch 191/200
# 27000/27000 [==============================] - 196s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2666 - Validation Error: 0.0119
# Epoch 192/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2667 - Validation Error: 0.0119
# Epoch 193/200
# 27000/27000 [==============================] - 196s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2666 - Validation Error: 0.0118
# Epoch 194/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2666 - Validation Error: 0.0118
# Epoch 195/200
# 27000/27000 [==============================] - 196s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2666 - Validation Error: 0.0119
# Epoch 196/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2666 - Validation Error: 0.0120
# Epoch 197/200
# 27000/27000 [==============================] - 196s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2666 - Validation Error: 0.0119
# Epoch 198/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2667 - Validation Error: 0.0121
# Epoch 199/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2668 - Validation Error: 0.0121
# Epoch 200/200
# 27000/27000 [==============================] - 195s 7ms/step - Loss: 0.2663 - Error: 0.0119
# Validation loss: 0.2666 - Validation Error: 0.0118

# %%
f, axs = plt.subplots(1,2,figsize=(15,5));

# Subplot 1 (Error in eigen_value)
axs[0].plot(model.train_epoch, model.train_loss, 'b', label='Training')
axs[0].plot(model.train_epoch, model.val_loss, 'g', label='Validation')
axs[0].legend()
axs[0].set_title('Loss vs training')
axs[0].set_xlabel('Number of epochs')
axs[0].set_ylabel('Loss')

# # Subplot 2 (Error in eigen_ec)
axs[1].plot(model.train_epoch, model.train_error, 'b', label='Training')
axs[1].plot(model.train_epoch, model.val_error, 'g', label='Validation')
axs[1].legend()
axs[1].set_title('Error vs training')
axs[1].set_xlabel('Number of epochs')
axs[1].set_ylabel('Accuracy');

# %% [markdown]
# ## Save model for future
#
# Save model for future use and restore it.

# %%
save_path = './final_model/my_model.ckpt'
model.save(save_path=save_path)
# Out:
# Model saved in path: ./final_model/my_model.ckpt

# %% [markdown]
# Restore saved model

# %%
save_path = './final_model/my_model.ckpt'

model = ImageCleaner()
model.restore(save_path=save_path)
# Out:
# INFO:tensorflow:Restoring parameters from ./final_model/my_model.ckpt
# Model restored.

# %% [markdown]
# ## Results
#
# Lets visually look at some of the results and see how well did the model recover the orignial image from the noisy image

# %%
X_predict = model.predict(X_test, batch_size = 20)

n = 10
canvas = np.empty((64 * n, 64*3))
for i in range(n):
    # Draw the generated digits
    canvas[i*64 : (i+1)*64, 0:64] = np.squeeze(X_test[i,:,:,:])
    canvas[i*64 : (i+1)*64, 64:128] = np.squeeze(X_predict[i,:,:,:])
    canvas[i*64 : (i+1)*64, 128:192] = np.squeeze(y_test[i,:,:,:])

print("Original Images")     
plt.figure(figsize=(15,5*n))
plt.imshow(canvas, cmap='plasma', vmin=0, vmax=1)
# Out:
# Original Images
